# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install -Uq fastai fastbook nbdev
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.7 MB/s eta 0:00:00

# %%
from fastai import *
from fastbook import *
from fastai.vision.all import *
from fastai.vision.widgets import ImageClassifierCleaner

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Art Style Recognizer
# Out:
# /content/drive/MyDrive/Art Style Recognizer

# %%
version = 5
img_path = 'test_images'
model_path = f'/content/drive/MyDrive/models/Art Style Recognizer/artStyle_recognizer-v5.pk1'

# %%
model= load_learner(model_path)

# %% [markdown]
# ##Inference 1

# %% [markdown]
# Target Art Nouveau

# %%
img = Image.open(f'{img_path}/Art Nouveau.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/Art Nouveau.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Art Nouveau',
#  tensor(0),
#  tensor([9.9998e-01, 4.2537e-08, 4.3978e-06, 8.5238e-07, 6.5833e-07, 7.4760e-07, 1.3954e-07, 2.4239e-07, 1.2646e-05, 6.5231e-07]))

# %% [markdown]
# ##Inference 2

# %%
img = Image.open(f'{img_path}/Constructivism art.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/Constructivism art.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Constructivism Art',
#  tensor(1),
#  tensor([5.8216e-04, 9.8546e-01, 8.7002e-03, 3.2719e-05, 1.7604e-03, 7.1776e-06, 3.3807e-03, 5.7478e-05, 1.3786e-05, 4.2638e-06]))

# %% [markdown]
# ##Inference 3

# %%
img = Image.open(f'{img_path}/Fauvism art.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x94>

# %%
model.predict(f'{img_path}/Fauvism art.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Fauvism Art',
#  tensor(4),
#  tensor([6.2096e-03, 4.0944e-04, 1.8319e-03, 1.1040e-03, 9.2304e-01, 4.8816e-04, 3.5003e-04, 6.0172e-02, 2.6959e-05, 6.3712e-03]))

# %% [markdown]
# ##Inference 4

# %%
img = Image.open(f'{img_path}/Gothic art.jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=85x128>

# %%
model.predict(f'{img_path}/Gothic art.jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Gothic Art',
#  tensor(5),
#  tensor([1.6873e-08, 9.2096e-08, 8.3444e-11, 3.4434e-08, 2.3747e-09, 1.0000e+00, 8.4142e-08, 4.3281e-07, 1.1190e-09, 3.5000e-08]))

# %% [markdown]
# ##Inference 5

# %%
img = Image.open(f'{img_path}/Minimalistic art.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=91x128>

# %%
model.predict(f'{img_path}/Minimalistic art.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Minimalism Art',
#  tensor(6),
#  tensor([2.4702e-04, 2.0241e-04, 6.1762e-05, 4.4820e-03, 7.2314e-05, 2.0735e-04, 9.7803e-01, 2.3668e-03, 4.5305e-03, 9.7993e-03]))
